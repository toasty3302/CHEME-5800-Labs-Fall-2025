# %% [markdown]
# # L1b: Let's test a notebook!
# In this test, we'll load [the `Include.jl` file](src/Include.jl) using [the `include(...)` method](https://docs.julialang.org/en/v1/base/base/#include), then we'll run some simple plotting commands using [methods exported by the `UnicodePlots.jl` package](https://github.com/JuliaPlots/UnicodePlots.jl)
#
# > __What does `include(...)` do?__ The [include command](https://docs.julialang.org/en/v1/base/base/#include) evaluates the contents of the input source file, [`Include.jl`](src/Include.jl), in the notebook's global scope. The `Include.jl` file sets paths, loads required external packages, etc. For additional information on functions and types used in this material, see the [Julia programming language documentation](https://docs.julialang.org/en/v1/).
#
# Let's go!
# ___

# %% [markdown]
# ## Setup, Data, and Prerequisites
#
# In our case, our `Include.jl` file will set paths so our notebook knows were to find things, and then will load external packages in the global score with [the `using` command](https://docs.julialang.org/en/v1/base/base/#using). This makes the content of the package visible to us.

# %%
# TODO: uncomment the line below, and run the cell to setup the computational Environment
include(joinpath(@__DIR__, "Include.jl")); # what is going on here?

# %% [markdown]
# Now that we have our environment setup, we can do some stuff.

# %% [markdown]
# ## Task 1: Let's build and visualize a Normal Distribution
# In this task, let's test our installation by smapling a model of [a Normal probability distribution](https://en.wikipedia.org/wiki/Normal_distribution), and then visualizing the samples. First, let's draw sample from the distribution and save them in the `samples::Array{Float64,1}` array.
#
# > __What is the `let` block?__ The [`let` block](https://docs.julialang.org/en/v1/base/base/#let) creates a new hard scope and optionally introduces new local bindings. Variables introduced inside a `let` block are local to that block and don't affect variables of the same name in the outer scope. In our case, the `let` block allows us to create local variables (`number_of_samples` and the local `samples`) that are only visible within the block, while the final value of `samples` is returned and assigned to the global variable `samples`. This is a common Julia pattern for organizing code and avoiding namespace pollution.
#
# We use [the built-in `randn(...)` method](https://docs.julialang.org/en/v1.11/stdlib/Random/#Base.randn) to generate samples from a standard normal distribution (mean 0, variance 1).

# %%
samples = let

    # initialize -
    number_of_samples = 10000; # set the number of samples we want to generate
    samples = nothing;

    # TODO: uncomment the line below to generate samples from a standard normal distribution
    samples = randn(number_of_samples);

    samples; # return
end;

# %% [markdown]
# Now, let's plot the `sample::Array{Float64,1}` array using [the `histogram(...)` method exported by the `UnicodePlots.jl` package](https://juliaplots.org/UnicodePlots.jl/dev/api/#UnicodePlots.histogram-Tuple%7BAbstractArray%7D).

# %%
let

    # initialize -
    data = samples; # random array
    number_of_bins = 20; # how many bins?
    vertical = false; # vertical or horizontal?
    closed = :left; # which side of the interval is closed?

    # TODO: uncomment the line below to make the histogram
    histogram(data, nbins=number_of_bins, vertical = vertical, closed = closed); 
end
# Out:
#                 ┌                                        ┐
#    [-4.5, -4.0) ┤▏ 1
#    [-4.0, -3.5) ┤▏ 2
#    [-3.5, -3.0) ┤▎ 11
#    [-3.0, -2.5) ┤▋ 36
#    [-2.5, -2.0) ┤███▏ 181
#    [-2.0, -1.5) ┤███████▎ 424
#    [-1.5, -1.0) ┤███████████████▋ 922
#    [-1.0, -0.5) ┤██████████████████████████▎ 1 541
#    [-0.5,  0.0) ┤█████████████████████████████████  1 944
#    [ 0.0,  0.5) ┤███████████████████████████████▉ 1 885
#    [ 0.5,  1.0) ┤████████████████████████▊ 1 467
#    [ 1.0,  1.5) ┤███████████████▊ 930
#    [ 1.5,  2.0) ┤███████▎ 423
#    [ 2.0,  2.5) ┤██▉ 175
#    [ 2.5,  3.0) ┤▊ 47
#    [ 3.0,  3.5) ┤▎ 8
#    [ 3.5,  4.0) ┤▏ 3
#                 └                                        ┘
#                                  Frequency

# %%
do_you_see_the_histogram = true; # TODO: update this flag if you see the histogram for the normal distribution

# %% [markdown]
# ## Task 2: Can we see code that we wrote?
# In this task, we check that methdos that we wrote (that were included when we called the `Include.jl` file) are now visible. In [the `HelloWorld.jl` file](src/HelloWorld.jl), we defined a simple method called `printgreeting()` that prints "Hello, World!" to the screen. Let's call it and see if it works.
#
# We'll save the response in the `message_that_we_get::String` variable:

# %%
message_that_we_get = nothing; # initialize to nothing
message_that_we_get = printgreeting() # TODO: call a method we defined, should return "Hello, World!"

# %% [markdown]
# ## Tests
# In the code block below, we check some values in your notebook and give you feedback on which items are correct or different. `Unhide` the code block below (if you are curious) about how we implemented the tests and what we are testing.

# %%
let

    @testset verbose = true "CHEME 4/5800 L1b Test Suite" begin
        
        # Test 1: Environment Setup
        @testset "Environment Setup Tests" begin
            @test @isdefined _DID_INCLUDE_GET_CALLED
            @test _DID_INCLUDE_GET_CALLED == true
            @test @isdefined printgreeting
        end
        
        # Test 2: Sample Generation Tests
        @testset "Sample Generation Tests" begin
            @test @isdefined samples
            @test isa(samples, Array{Float64,1})
            @test length(samples) == 10000
            @test !isempty(samples)
            
            # Statistical properties of normal distribution
            sample_mean = Statistics.mean(samples)
            sample_std = Statistics.std(samples)
            @test abs(sample_mean) < 0.1
            @test abs(sample_std - 1.0) < 0.1
        end
        
        # Test 3: Histogram Flag Tests
        @testset "Histogram Flag Tests" begin
            @test @isdefined do_you_see_the_histogram
            @test isa(do_you_see_the_histogram, Bool)
        end
        
        # Test 4: HelloWorld Function Tests
        @testset "HelloWorld Function Tests" begin
            @test @isdefined message_that_we_get
            @test isa(message_that_we_get, String)
            @test message_that_we_get == "Hello World!"
            
            # Test the function directly
            greeting = printgreeting()
            @test greeting == "Hello World!"
            @test isa(greeting, String)
        end
        
        # Test 5: Data Type and Structure Tests
        @testset "Data Type and Structure Tests" begin
            # Test that all variables have expected types
            @test isa(samples, Vector)
            @test eltype(samples) == Float64
            
            # Test that samples are finite (no NaN or Inf values)
            @test all(isfinite.(samples))
            
            # Test range - normal distribution should have most values within ±4 standard deviations
            extreme_values = count(abs.(samples) .> 4.0)
            @test extreme_values < 100
        end
        
        # Test 6: Package and Function Availability Tests
        @testset "Package and Function Availability Tests" begin
            @test @isdefined histogram
            @test @isdefined randn
        end
    end
end;
# Out:
# Sample Generation Tests: Test Failed at c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:14
#   Expression: #= c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:14 =# @isdefined samples
#
# Stacktrace:
#  [1] macro expansion
#    @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:680 [inlined]
#  [2] macro expansion
#    @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:14 [inlined]
#  [3] macro expansion
#    @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#  [4] macro expansion
#    @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:14 [inlined]
#  [5] macro expansion
#    @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#  [6] top-level scope
#    @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:6
# Sample Generation Tests: Error During Test at c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:15
#   Test threw exception
#   Expression: samples isa Array{Float64, 1}
#   UndefVarError: `samples` not defined in `Main`
#   Suggestion: check for spelling errors or missing imports.
#   Stacktrace:
#    [1] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:677 [inlined]
#    [2] macro expansion
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:15 [inlined]
#    [3] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#    [4] macro expansion
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:14 [inlined]
#    [5] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#    [6] top-level scope
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:6
# Sample Generation Tests: Error During Test at c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:16
#   Test threw exception
#   Expression: length(samples) == 10000
#   UndefVarError: `samples` not defined in `Main`
#   Suggestion: check for spelling errors or missing imports.
#   Stacktrace:
#    [1] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:677 [inlined]
#    [2] macro expansion
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:16 [inlined]
#    [3] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#    [4] macro expansion
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:14 [inlined]
#    [5] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#    [6] top-level scope
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:6
# Sample Generation Tests: Error During Test at c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:17
#   Test threw exception
#   Expression: !(isempty(samples))
#   UndefVarError: `samples` not defined in `Main`
#   Suggestion: check for spelling errors or missing imports.
#   Stacktrace:
#    [1] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:677 [inlined]
#    [2] macro expansion
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:17 [inlined]
#    [3] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#    [4] macro expansion
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:14 [inlined]
#    [5] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#    [6] top-level scope
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:6
# Sample Generation Tests: Error During Test at c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:13
#   Got exception outside of a @test
#   UndefVarError: `samples` not defined in `Main`
#   Suggestion: check for spelling errors or missing imports.
#   Stacktrace:
#     [1] macro expansion
#       @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:20 [inlined]
#     [2] macro expansion
#       @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#     [3] macro expansion
#       @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:14 [inlined]
#     [4] macro expansion
#       @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#     [5] top-level scope
#       @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:6
#     [6] eval
#       @ .\boot.jl:430 [inlined]
#     [7] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#       @ Base .\loading.jl:2734
#     [8] #invokelatest#2
#       @ .\essentials.jl:1055 [inlined]
#     [9] invokelatest
#       @ .\essentials.jl:1052 [inlined]
#    [10] (::VSCodeServer.var"#217#218"{VSCodeServer.NotebookRunCellArguments, String})()
#       @ VSCodeServer c:\Users\billn\.vscode\extensions\julialang.language-julia-1.149.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:24
#    [11] withpath(f::VSCodeServer.var"#217#218"{VSCodeServer.NotebookRunCellArguments, String}, path::String)
#       @ VSCodeServer c:\Users\billn\.vscode\extensions\julialang.language-julia-1.149.2\scripts\packages\VSCodeServer\src\repl.jl:276
#    [12] notebook_runcell_request(conn::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, params::VSCodeServer.NotebookRunCellArguments, token::VSCodeServer.CancellationTokens.CancellationToken)
#       @ VSCodeServer c:\Users\billn\.vscode\extensions\julialang.language-julia-1.149.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:13
#    [13] dispatch_msg(x::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, dispatcher::VSCodeServer.JSONRPC.MsgDispatcher, msg::VSCodeServer.JSONRPC.Request)
#       @ VSCodeServer.JSONRPC c:\Users\billn\.vscode\extensions\julialang.language-julia-1.149.2\scripts\packages\JSONRPC\src\typed.jl:68
#    [14] serve_notebook(pipename::String, debugger_pipename::String, outputchannel_logger::Base.CoreLogging.SimpleLogger; error_handler::var"#5#10"{String})
#       @ VSCodeServer c:\Users\billn\.vscode\extensions\julialang.language-julia-1.149.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:147
#    [15] top-level scope
#       @ c:\Users\billn\.vscode\extensions\julialang.language-julia-1.149.2\scripts\notebook\notebook.jl:35
# Histogram Flag Tests: Test Failed at c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:28
#   Expression: #= c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:28 =# @isdefined do_you_see_the_histogram
#
# Stacktrace:
#  [1] macro expansion
#    @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:680 [inlined]
#  [2] macro expansion
#    @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:28 [inlined]
#  [3] macro expansion
#    @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#  [4] macro expansion
#    @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:28 [inlined]
#  [5] macro expansion
#    @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#  [6] top-level scope
#    @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:6
# Histogram Flag Tests: Error During Test at c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:29
#   Test threw exception
#   Expression: do_you_see_the_histogram isa Bool
#   UndefVarError: `do_you_see_the_histogram` not defined in `Main`
#   Suggestion: check for spelling errors or missing imports.
#   Stacktrace:
#    [1] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:677 [inlined]
#    [2] macro expansion
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:29 [inlined]
#    [3] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#    [4] macro expansion
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:28 [inlined]
#    [5] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#    [6] top-level scope
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:6
# HelloWorld Function Tests: Test Failed at c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:34
#   Expression: #= c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:34 =# @isdefined message_that_we_get
#
# Stacktrace:
#  [1] macro expansion
#    @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:680 [inlined]
#  [2] macro expansion
#    @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:34 [inlined]
#  [3] macro expansion
#    @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#  [4] macro expansion
#    @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:34 [inlined]
#  [5] macro expansion
#    @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#  [6] top-level scope
#    @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:6
# HelloWorld Function Tests: Error During Test at c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:35
#   Test threw exception
#   Expression: message_that_we_get isa String
#   UndefVarError: `message_that_we_get` not defined in `Main`
#   Suggestion: check for spelling errors or missing imports.
#   Stacktrace:
#    [1] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:677 [inlined]
#    [2] macro expansion
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:35 [inlined]
#    [3] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#    [4] macro expansion
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:34 [inlined]
#    [5] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#    [6] top-level scope
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:6
# HelloWorld Function Tests: Error During Test at c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:36
#   Test threw exception
#   Expression: message_that_we_get == "Hello World!"
#   UndefVarError: `message_that_we_get` not defined in `Main`
#   Suggestion: check for spelling errors or missing imports.
#   Stacktrace:
#    [1] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:677 [inlined]
#    [2] macro expansion
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:36 [inlined]
#    [3] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#    [4] macro expansion
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:34 [inlined]
#    [5] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#    [6] top-level scope
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:6
# Data Type and Structure Tests: Error During Test at c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:47
#   Test threw exception
#   Expression: samples isa Vector
#   UndefVarError: `samples` not defined in `Main`
#   Suggestion: check for spelling errors or missing imports.
#   Stacktrace:
#    [1] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:677 [inlined]
#    [2] macro expansion
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:47 [inlined]
#    [3] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#    [4] macro expansion
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:47 [inlined]
#    [5] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#    [6] top-level scope
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:6
# Data Type and Structure Tests: Error During Test at c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:48
#   Test threw exception
#   Expression: eltype(samples) == Float64
#   UndefVarError: `samples` not defined in `Main`
#   Suggestion: check for spelling errors or missing imports.
#   Stacktrace:
#    [1] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:677 [inlined]
#    [2] macro expansion
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:48 [inlined]
#    [3] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#    [4] macro expansion
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:47 [inlined]
#    [5] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#    [6] top-level scope
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:6
# Data Type and Structure Tests: Error During Test at c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:51
#   Test threw exception
#   Expression: all(isfinite.(samples))
#   UndefVarError: `samples` not defined in `Main`
#   Suggestion: check for spelling errors or missing imports.
#   Stacktrace:
#    [1] macro expansion
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:51 [inlined]
#    [2] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:677 [inlined]
#    [3] macro expansion
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:51 [inlined]
#    [4] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#    [5] macro expansion
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:47 [inlined]
#    [6] macro expansion
#      @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#    [7] top-level scope
#      @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:6
# Data Type and Structure Tests: Error During Test at c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:45
#   Got exception outside of a @test
#   UndefVarError: `samples` not defined in `Main`
#   Suggestion: check for spelling errors or missing imports.
#   Stacktrace:
#     [1] macro expansion
#       @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:54 [inlined]
#     [2] macro expansion
#       @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#     [3] macro expansion
#       @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:47 [inlined]
#     [4] macro expansion
#       @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1709 [inlined]
#     [5] top-level scope
#       @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:6
#     [6] eval
#       @ .\boot.jl:430 [inlined]
#     [7] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#       @ Base .\loading.jl:2734
#     [8] #invokelatest#2
#       @ .\essentials.jl:1055 [inlined]
#     [9] invokelatest
#       @ .\essentials.jl:1052 [inlined]
#    [10] (::VSCodeServer.var"#217#218"{VSCodeServer.NotebookRunCellArguments, String})()
#       @ VSCodeServer c:\Users\billn\.vscode\extensions\julialang.language-julia-1.149.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:24
#    [11] withpath(f::VSCodeServer.var"#217#218"{VSCodeServer.NotebookRunCellArguments, String}, path::String)
#       @ VSCodeServer c:\Users\billn\.vscode\extensions\julialang.language-julia-1.149.2\scripts\packages\VSCodeServer\src\repl.jl:276
#    [12] notebook_runcell_request(conn::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, params::VSCodeServer.NotebookRunCellArguments, token::VSCodeServer.CancellationTokens.CancellationToken)
#       @ VSCodeServer c:\Users\billn\.vscode\extensions\julialang.language-julia-1.149.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:13
#    [13] dispatch_msg(x::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, dispatcher::VSCodeServer.JSONRPC.MsgDispatcher, msg::VSCodeServer.JSONRPC.Request)
#       @ VSCodeServer.JSONRPC c:\Users\billn\.vscode\extensions\julialang.language-julia-1.149.2\scripts\packages\JSONRPC\src\typed.jl:68
#    [14] serve_notebook(pipename::String, debugger_pipename::String, outputchannel_logger::Base.CoreLogging.SimpleLogger; error_handler::var"#5#10"{String})
#       @ VSCodeServer c:\Users\billn\.vscode\extensions\julialang.language-julia-1.149.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:147
#    [15] top-level scope
#       @ c:\Users\billn\.vscode\extensions\julialang.language-julia-1.149.2\scripts\notebook\notebook.jl:35
# Test Summary:                             | Pass  Fail  Error  Total  Time
# CHEME 4/5800 L1b Test Suite               |    7     3     11     21  8.5s
#   Environment Setup Tests                 |    3                   3  0.5s
#   Sample Generation Tests                 |          1      4      5  7.6s
#   Histogram Flag Tests                    |          1      1      2  0.1s
#   HelloWorld Function Tests               |    2     1      2      5  0.1s
#   Data Type and Structure Tests           |                 4      4  0.2s
#   Package and Function Availability Tests |    2                   2  0.0s
# Some tests did not pass: 7 passed, 3 failed, 11 errored, 0 broken.
#
#
#
# Stacktrace:
#
#  [1] finish(ts::Test.DefaultTestSet; print_results::Bool)
#
#    @ Test C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1259
#
#  [2] finish(ts::Test.DefaultTestSet)
#
#    @ Test C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1234
#
#  [3] macro expansion
#
#    @ C:\Users\billn\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Test\src\Test.jl:1725 [inlined]
#
#  [4] top-level scope
#
#    @ c:\Users\billn\Downloads\CHEM4800\CHEME-5800-Labs-Fall-2025\labs\week-1\L1b\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:6
